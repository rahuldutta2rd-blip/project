# %%
from fastapi import FastAPI
from sqlalchemy import create_engine, text

app = FastAPI()

engine = create_engine("postgresql://neondb_owner:npg_7sv0JmSfOikH@ep-shy-truth-an1aj3mt-pooler.c-6.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require")

# %%
@app.get("/autocomplete")
def autocomplete(q: str, state: str = None, district: str = None):
    base_query = """
        SELECT 
            v.name as village,
            sd.name as sub_district,
            d.name as district,
            s.name as state
        FROM villages v
        JOIN sub_districts sd ON v.sub_district_id = sd.id
        JOIN districts d ON sd.district_id = d.id
        JOIN states s ON d.state_id = s.id
        WHERE v.name ILIKE :q
    """

    params = {"q": f"%{q}%"}

    if state:
        base_query += " AND s.name ILIKE :state"
        params["state"] = f"%{state}%"

    if district:
        base_query += " AND d.name ILIKE :district"
        params["district"] = f"%{district}%"

    base_query += " LIMIT 20"

    with engine.connect() as conn:
        result = conn.execute(text(base_query), params)
        data = [
            {
                **dict(row._mapping),
                "formatted": f"{row.village.title()}, {row.sub_district.title()}, {row.district.title()}, {row.state.title()}, India"
            }
            for row in result
        ]

    return data

# %%
# !pip install uvicorn fastapi
# Out:
# Requirement already satisfied: uvicorn in c:\users\chint\anaconda3\lib\site-packages (0.46.0)
# Requirement already satisfied: fastapi in c:\users\chint\anaconda3\lib\site-packages (0.136.1)
# Requirement already satisfied: click>=7.0 in c:\users\chint\anaconda3\lib\site-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in c:\users\chint\anaconda3\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: starlette>=0.46.0 in c:\users\chint\anaconda3\lib\site-packages (from fastapi) (1.0.0)
# Requirement already satisfied: pydantic>=2.9.0 in c:\users\chint\anaconda3\lib\site-packages (from fastapi) (2.10.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\chint\anaconda3\lib\site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\chint\anaconda3\lib\site-packages (from fastapi) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\chint\anaconda3\lib\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: colorama in c:\users\chint\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chint\anaconda3\lib\site-packages (from pydantic>=2.9.0->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\chint\anaconda3\lib\site-packages (from pydantic>=2.9.0->fastapi) (2.27.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\chint\anaconda3\lib\site-packages (from starlette>=0.46.0->fastapi) (4.7.0)
# Requirement already satisfied: idna>=2.8 in c:\users\chint\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\chint\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (1.3.0)

# %%
# !dir
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is ECF8-CD61
#
#  Directory of C:\Users\chint\Project\backend
#
# 26-04-2026  04:02    <DIR>          .
# 26-04-2026  03:36    <DIR>          ..
# 26-04-2026  03:55    <DIR>          .ipynb_checkpoints
# 26-04-2026  04:00             5,285 main.ipynb
# 26-04-2026  04:02               903 main.py
# 26-04-2026  04:02    <DIR>          __pycache__
#                2 File(s)          6,188 bytes
#                4 Dir(s)  247,092,711,424 bytes free

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\chint\Project\backend

# %%
pip install slowapi
# Out:
# Collecting slowapi
#   Downloading slowapi-0.1.9-py3-none-any.whl.metadata (3.0 kB)
# Collecting limits>=2.3 (from slowapi)
#   Downloading limits-5.8.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: deprecated>=1.2 in c:\users\chint\anaconda3\lib\site-packages (from limits>=2.3->slowapi) (1.2.13)
# Requirement already satisfied: packaging>=21 in c:\users\chint\anaconda3\lib\site-packages (from limits>=2.3->slowapi) (24.2)
# Requirement already satisfied: typing-extensions in c:\users\chint\anaconda3\lib\site-packages (from limits>=2.3->slowapi) (4.12.2)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\chint\anaconda3\lib\site-packages (from deprecated>=1.2->limits>=2.3->slowapi) (1.17.0)
# Downloading slowapi-0.1.9-py3-none-any.whl (14 kB)
# Downloading limits-5.8.0-py3-none-any.whl (60 kB)
# Installing collected packages: limits, slowapi
#
#    ---------------------------------------- 2/2 [slowapi]
#
# Successfully installed limits-5.8.0 slowapi-0.1.9
# Note: you may need to restart the kernel to use updated packages.

# %%
from slowapi import Limiter
from slowapi.util import get_remote_address

limiter = Limiter(key_func=get_remote_address)
app.state.limiter = limiter

# %%
pip install redis
# Out:
# Collecting redis
#   Downloading redis-7.4.0-py3-none-any.whl.metadata (12 kB)
# Downloading redis-7.4.0-py3-none-any.whl (409 kB)
# Installing collected packages: redis
# Successfully installed redis-7.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import redis
import json

r = redis.Redis(host='localhost', port=6379, db=0)
